# %%
import pandas as pd
import json

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 1: Use Python Dictionary Methods
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Iterate through the DataFrame and convert each row to a dictionary.
# 3. Iterate through each dictionary and do the following:
#     * Extract the dictionary values from the keys using Python list comprehension.
#     * Add the values for each row to a new list.
# 4. Create a new DataFrame with the retrieved data.
# 5. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)
backer_info = "backer_info.csv"
backer_df = pd.read_csv(backer_info)
backer_df.head()
# Out:
#                                                                                           backer_info
# 0        {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1        {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2          {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4               {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}

# %%
# Iterate through the backers DataFrame and convert each row to a dictionary.
for index, value in backer_df.iterrows():

    # Iterate through each dictionary (row) and get the values for each row using list comprehension.
    print(value)
    
    # Append the list of values for each row to a list. 
    

# Print out the list of values for each row.
# Out:
# backer_info    {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# Name: 0, dtype: object
# backer_info    {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# Name: 1, dtype: object
# backer_info    {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# Name: 2, dtype: object
# backer_info    {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# Name: 3, dtype: object
# backer_info    {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# Name: 4, dtype: object
# backer_info    {"backer_id": "lh382", "cf_id": 563, "name": "Lambert Huber", "email": "lhuber@live.com"}
# Name: 5, dtype: object
# backer_info    {"backer_id": "em444", "cf_id": 563, "name": "Emmy Morin", "email": "emorin@live.com"}
# Name: 6, dtype: object
# backer_info    {"backer_id": "at582", "cf_id": 1572, "name": "Armonda Trani", "email": "atrani@live.com"}
# Name: 7, dtype: object
# backer_info    {"backer_id": "id772", "cf_id": 1911, "name": "Ilana Duke", "email": "iduke@outlook.com"}
# Name: 8, dtype: object
# backer_info    {"backer_id": "lw275", "cf_id": 65, "name": "Leigha Wright", "email": "lwright@live.com"}
# Name: 9, dtype: object
# backer_info    {"backer_id": "ub509", "cf_id": 65, "name": "Uwe Becker", "email": "ubecker@yahoo.com"}
# Name: 10, dtype: object
# backer_info    {"backer_id": "ha915", "cf_id": 1572, "name": "Hawa Audy", "email": "haudy@gmail.com"}
# Name: 11, dtype: object
# backer_info    {"backer_id": "bb881", "cf_id": 968, "name": "Bia Bonura", "email": "bbonura@yahoo.com"}
# Name: 12, dtype: object
# backer_info    {"backer_id": "mg332", "cf_id": 65, "name": "Michel Garner", "email": "mgarner@protonmail.com"}
# Name: 13, dtype: object
# backer_info    {"backer_id": "kd700", "cf_id": 1572, "name": "Karole Dunn", "email": "kdunn@yahoo.com"}
# Name: 14, dtype: object
# backer_info    {"backer_id": "as695", "cf_id": 563, "name": "Arndt Schreiber", "email": "aschreiber@yahoo.com"}
# Name: 15, dtype: object
# backer_info    {"backer_id": "iv513", "cf_id": 65, "name": "Imen Villeneuve", "email": "ivilleneuve@yahoo.com"}
# Name: 16, dtype: object
# backer_info    {"backer_id": "ab842", "cf_id": 65, "name": "Alcina Bonadonna", "email": "abonadonna@yandex.com"}
# Name: 17, dtype: object
# backer_info    {"backer_id": "re181", "cf_id": 1114, "name": "Raelene Espinoza", "email": "respinoza@outlook.com"}
# Name: 18, dtype: object
# backer_info    {"backer_id": "kn133", "cf_id": 65, "name": "Kati Nash", "email": "knash@protonmail.com"}
# Name: 19, dtype: object
# backer_info    {"backer_id": "gj893", "cf_id": 65, "name": "Georg Jager", "email": "gjager@yahoo.com"}
# Name: 20, dtype: object
# backer_info    {"backer_id": "vp915", "cf_id": 948, "name": "Virgilio Paolella", "email": "vpaolella@gmail.com"}
# Name: 21, dtype: object
# backer_info    {"backer_id": "ja995", "cf_id": 563, "name": "Jerrica Avila", "email": "javila@protonmail.com"}
# Name: 22, dtype: object
# backer_info    {"backer_id": "ga249", "cf_id": 563, "name": "Gianni Achterberg", "email": "gachterberg@live.com"}
# Name: 23, dtype: object
# backer_info    {"backer_id": "td403", "cf_id": 65, "name": "Timoteo Dion", "email": "tdion@gmail.com"}
# Name: 24, dtype: object
# backer_info    {"backer_id": "tv463", "cf_id": 1572, "name": "Teodoro Verno", "email": "tverno@yandex.com"}
# Name: 25, dtype: object
# backer_info    {"backer_id": "mw606", "cf_id": 65, "name": "Morris Waller", "email": "mwaller@protonmail.com"}
# Name: 26, dtype: object
# backer_info    {"backer_id": "hc648", "cf_id": 65, "name": "Hans Chen", "email": "hchen@yandex.com"}
# Name: 27, dtype: object
# backer_info    {"backer_id": "ta379", "cf_id": 563, "name": "Trilby Auer", "email": "tauer@yahoo.com"}
# Name: 28, dtype: object
# backer_info    {"backer_id": "tj583", "cf_id": 1572, "name": "Theola Jodoin", "email": "tjodoin@yandex.com"}
# Name: 29, dtype: object
# backer_info    {"backer_id": "tc559", "cf_id": 65, "name": "Tova Capri", "email": "tcapri@live.com"}
# Name: 30, dtype: object
# backer_info    {"backer_id": "ww629", "cf_id": 65, "name": "Wanda Walton", "email": "wwalton@protonmail.com"}
# Name: 31, dtype: object
# backer_info    {"backer_id": "jg155", "cf_id": 1572, "name": "Justine Gill", "email": "jgill@yahoo.com"}
# Name: 32, dtype: object
# backer_info    {"backer_id": "jd328", "cf_id": 1911, "name": "Julee Doyle", "email": "jdoyle@gmail.com"}
# Name: 33, dtype: object
# backer_info    {"backer_id": "ld239", "cf_id": 65, "name": "Lisbeth Deliso", "email": "ldeliso@gmail.com"}
# Name: 34, dtype: object
# backer_info    {"backer_id": "cv918", "cf_id": 968, "name": "Carl Valdez", "email": "cvaldez@gmail.com"}
# Name: 35, dtype: object
# backer_info    {"backer_id": "kb145", "cf_id": 563, "name": "Kelyan Butler", "email": "kbutler@yahoo.com"}
# Name: 36, dtype: object
# backer_info    {"backer_id": "dw578", "cf_id": 65, "name": "Donat Weber", "email": "dweber@live.com"}
# Name: 37, dtype: object
# backer_info    {"backer_id": "ad511", "cf_id": 65, "name": "Alethia Delorme", "email": "adelorme@outlook.com"}
# Name: 38, dtype: object
# backer_info    {"backer_id": "db633", "cf_id": 65, "name": "Darrell Bernardi", "email": "dbernardi@yandex.com"}
# Name: 39, dtype: object
# backer_info    {"backer_id": "cr369", "cf_id": 65, "name": "Carina Reeves", "email": "creeves@gmail.com"}
# Name: 40, dtype: object
# backer_info    {"backer_id": "mr978", "cf_id": 65, "name": "Marvin Ruiz", "email": "mruiz@outlook.com"}
# Name: 41, dtype: object
# backer_info    {"backer_id": "md167", "cf_id": 1572, "name": "Mariabella Duerr", "email": "mduerr@live.com"}
# Name: 42, dtype: object
# backer_info    {"backer_id": "jr877", "cf_id": 1572, "name": "Jeni Ricco", "email": "jricco@live.com"}
# Name: 43, dtype: object
# backer_info    {"backer_id": "om753", "cf_id": 65, "name": "Otto Munoz", "email": "omunoz@yahoo.com"}
# Name: 44, dtype: object
# backer_info    {"backer_id": "ng231", "cf_id": 1114, "name": "Nesrine Gensch", "email": "ngensch@yandex.com"}
# Name: 45, dtype: object
# backer_info    {"backer_id": "tl316", "cf_id": 65, "name": "Tullio Lejeune", "email": "tlejeune@outlook.com"}
# Name: 46, dtype: object
# backer_info    {"backer_id": "dl139", "cf_id": 563, "name": "Dreama Lonardo", "email": "dlonardo@live.com"}
# Name: 47, dtype: object
# backer_info    {"backer_id": "mw253", "cf_id": 968, "name": "Maryrose West", "email": "mwest@live.com"}
# Name: 48, dtype: object
# backer_info    {"backer_id": "im424", "cf_id": 65, "name": "Irina Mays", "email": "imays@yandex.com"}
# Name: 49, dtype: object
# backer_info    {"backer_id": "mb131", "cf_id": 968, "name": "Marcelo Brose", "email": "mbrose@protonmail.com"}
# Name: 50, dtype: object
# backer_info    {"backer_id": "nc240", "cf_id": 1572, "name": "Nestor Coutant", "email": "ncoutant@gmail.com"}
# Name: 51, dtype: object
# backer_info    {"backer_id": "ab318", "cf_id": 1572, "name": "Aloysius Braun", "email": "abraun@live.com"}
# Name: 52, dtype: object
# backer_info    {"backer_id": "af301", "cf_id": 65, "name": "Amos Ferre", "email": "aferre@gmail.com"}
# Name: 53, dtype: object
# backer_info    {"backer_id": "bl736", "cf_id": 563, "name": "Brigitte Lynch", "email": "blynch@outlook.com"}
# Name: 54, dtype: object
# backer_info    {"backer_id": "ar957", "cf_id": 65, "name": "Alegra Ramsey", "email": "aramsey@yahoo.com"}
# Name: 55, dtype: object
# backer_info    {"backer_id": "cb474", "cf_id": 968, "name": "Conchita Beitel", "email": "cbeitel@gmail.com"}
# Name: 56, dtype: object
# backer_info    {"backer_id": "dv246", "cf_id": 1572, "name": "Donnie Vernet", "email": "dvernet@protonmail.com"}
# Name: 57, dtype: object
# backer_info    {"backer_id": "cj111", "cf_id": 563, "name": "Cyril Jones", "email": "cjones@protonmail.com"}
# Name: 58, dtype: object
# backer_info    {"backer_id": "lh765", "cf_id": 563, "name": "Lucinda Hays", "email": "lhays@outlook.com"}
# Name: 59, dtype: object
# backer_info    {"backer_id": "wh697", "cf_id": 65, "name": "Walter Hermann", "email": "whermann@outlook.com"}
# Name: 60, dtype: object
# backer_info    {"backer_id": "eb714", "cf_id": 65, "name": "Emil Blanc", "email": "eblanc@protonmail.com"}
# Name: 61, dtype: object
# backer_info    {"backer_id": "ec356", "cf_id": 1572, "name": "Eldwin Cesare", "email": "ecesare@protonmail.com"}
# Name: 62, dtype: object
# backer_info    {"backer_id": "yh129", "cf_id": 65, "name": "Yusuf Hudson", "email": "yhudson@protonmail.com"}
# Name: 63, dtype: object
# backer_info    {"backer_id": "as494", "cf_id": 65, "name": "Arrigo Salazar", "email": "asalazar@gmail.com"}
# Name: 64, dtype: object
# backer_info    {"backer_id": "lb146", "cf_id": 563, "name": "Levi Beck", "email": "lbeck@gmail.com"}
# Name: 65, dtype: object
# backer_info    {"backer_id": "cc470", "cf_id": 563, "name": "Celinda Caillet", "email": "ccaillet@yandex.com"}
# Name: 66, dtype: object
# backer_info    {"backer_id": "mm239", "cf_id": 563, "name": "Marcus Medici", "email": "mmedici@gmail.com"}
# Name: 67, dtype: object
# backer_info    {"backer_id": "dg360", "cf_id": 65, "name": "Daysi Gamble", "email": "dgamble@yahoo.com"}
# Name: 68, dtype: object
# backer_info    {"backer_id": "rh399", "cf_id": 1572, "name": "Rory Hildebrand", "email": "rhildebrand@yahoo.com"}
# Name: 69, dtype: object
# backer_info    {"backer_id": "hr430", "cf_id": 65, "name": "Heini Raffin", "email": "hraffin@yahoo.com"}
# Name: 70, dtype: object
# backer_info    {"backer_id": "ar829", "cf_id": 65, "name": "Anna Randall", "email": "arandall@outlook.com"}
# Name: 71, dtype: object
# backer_info    {"backer_id": "sw301", "cf_id": 65, "name": "Sharmaine Weber", "email": "sweber@yahoo.com"}
# Name: 72, dtype: object
# backer_info    {"backer_id": "rr355", "cf_id": 65, "name": "Ranee Renault", "email": "rrenault@outlook.com"}
# Name: 73, dtype: object
# backer_info    {"backer_id": "zc515", "cf_id": 1572, "name": "Zak Cianciola", "email": "zcianciola@yahoo.com"}
# Name: 74, dtype: object
# backer_info    {"backer_id": "gp101", "cf_id": 65, "name": "Granville Potts", "email": "gpotts@gmail.com"}
# Name: 75, dtype: object
# backer_info    {"backer_id": "bm741", "cf_id": 65, "name": "Bo Marsh", "email": "bmarsh@live.com"}
# Name: 76, dtype: object
# backer_info    {"backer_id": "jd148", "cf_id": 65, "name": "Jay Duerr", "email": "jduerr@yahoo.com"}
# Name: 77, dtype: object
# backer_info    {"backer_id": "mm632", "cf_id": 65, "name": "Milla Morin", "email": "mmorin@yahoo.com"}
# Name: 78, dtype: object
# backer_info    {"backer_id": "ls884", "cf_id": 65, "name": "Leanne Savage", "email": "lsavage@gmail.com"}
# Name: 79, dtype: object
# backer_info    {"backer_id": "sp364", "cf_id": 968, "name": "Silvana Patton", "email": "spatton@live.com"}
# Name: 80, dtype: object
# backer_info    {"backer_id": "hh963", "cf_id": 65, "name": "Harvey Hoch", "email": "hhoch@outlook.com"}
# Name: 81, dtype: object
# backer_info    {"backer_id": "sb272", "cf_id": 65, "name": "Seth Berthier", "email": "sberthier@protonmail.com"}
# Name: 82, dtype: object
# backer_info    {"backer_id": "et566", "cf_id": 1114, "name": "Eugen Trani", "email": "etrani@protonmail.com"}
# Name: 83, dtype: object
# backer_info    {"backer_id": "sd421", "cf_id": 1572, "name": "Santina Dieter", "email": "sdieter@yahoo.com"}
# Name: 84, dtype: object
# backer_info    {"backer_id": "tg563", "cf_id": 65, "name": "Trinh Gregoire", "email": "tgregoire@live.com"}
# Name: 85, dtype: object
# backer_info    {"backer_id": "kc571", "cf_id": 968, "name": "Karin Celano", "email": "kcelano@yandex.com"}
# Name: 86, dtype: object
# backer_info    {"backer_id": "sd121", "cf_id": 1114, "name": "Sofia Decker", "email": "sdecker@yahoo.com"}
# Name: 87, dtype: object
# backer_info    {"backer_id": "sk744", "cf_id": 65, "name": "Sherise Keller", "email": "skeller@outlook.com"}
# Name: 88, dtype: object
# backer_info    {"backer_id": "km642", "cf_id": 65, "name": "Kirby Michel", "email": "kmichel@gmail.com"}
# Name: 89, dtype: object
# backer_info    {"backer_id": "fu320", "cf_id": 65, "name": "Florentine Ungaro", "email": "fungaro@yandex.com"}
# Name: 90, dtype: object
# backer_info    {"backer_id": "ld180", "cf_id": 1911, "name": "Louise Dejesus", "email": "ldejesus@yandex.com"}
# Name: 91, dtype: object
# backer_info    {"backer_id": "ds377", "cf_id": 65, "name": "Daniele Suarez", "email": "dsuarez@yahoo.com"}
# Name: 92, dtype: object
# backer_info    {"backer_id": "bb692", "cf_id": 65, "name": "Beckie Buchholz", "email": "bbuchholz@live.com"}
# Name: 93, dtype: object
# backer_info    {"backer_id": "wd557", "cf_id": 563, "name": "William Dickson", "email": "wdickson@yandex.com"}
# Name: 94, dtype: object
# backer_info    {"backer_id": "jd905", "cf_id": 65, "name": "Jolie Daugherty", "email": "jdaugherty@gmail.com"}
# Name: 95, dtype: object
# backer_info    {"backer_id": "dd770", "cf_id": 65, "name": "Detta Dressler", "email": "ddressler@yahoo.com"}
# Name: 96, dtype: object
# backer_info    {"backer_id": "cv698", "cf_id": 238, "name": "Clifton Villette", "email": "cvillette@outlook.com"}
# Name: 97, dtype: object
# backer_info    {"backer_id": "cn307", "cf_id": 968, "name": "Cythia Netti", "email": "cnetti@outlook.com"}
# Name: 98, dtype: object
# backer_info    {"backer_id": "eb198", "cf_id": 1572, "name": "Elsbeth Butler", "email": "ebutler@yahoo.com"}
# Name: 99, dtype: object
# backer_info    {"backer_id": "am869", "cf_id": 65, "name": "Ambrine Mann", "email": "amann@yahoo.com"}
# Name: 100, dtype: object
# backer_info    {"backer_id": "gr400", "cf_id": 1911, "name": "Gerald Robert", "email": "grobert@protonmail.com"}
# Name: 101, dtype: object
# backer_info    {"backer_id": "az657", "cf_id": 563, "name": "Assunta Zezza", "email": "azezza@live.com"}
# Name: 102, dtype: object
# backer_info    {"backer_id": "kc598", "cf_id": 1572, "name": "Kerstin Campbell", "email": "kcampbell@protonmail.com"}
# Name: 103, dtype: object
# backer_info    {"backer_id": "lb588", "cf_id": 65, "name": "Lino Brock", "email": "lbrock@outlook.com"}
# Name: 104, dtype: object
# backer_info    {"backer_id": "rl866", "cf_id": 65, "name": "Rubie Levasseur", "email": "rlevasseur@gmail.com"}
# Name: 105, dtype: object
# backer_info    {"backer_id": "jf340", "cf_id": 65, "name": "Johann Flowers", "email": "jflowers@live.com"}
# Name: 106, dtype: object
# backer_info    {"backer_id": "tb384", "cf_id": 1572, "name": "Thibaud Bullock", "email": "tbullock@yahoo.com"}
# Name: 107, dtype: object
# backer_info    {"backer_id": "dg290", "cf_id": 65, "name": "Dan Gallois", "email": "dgallois@outlook.com"}
# Name: 108, dtype: object
# backer_info    {"backer_id": "rr518", "cf_id": 65, "name": "Rolf Richards", "email": "rrichards@live.com"}
# Name: 109, dtype: object
# backer_info    {"backer_id": "sh779", "cf_id": 968, "name": "Selyan Hoffman", "email": "shoffman@outlook.com"}
# Name: 110, dtype: object
# backer_info    {"backer_id": "lw525", "cf_id": 65, "name": "Lucca Weber", "email": "lweber@live.com"}
# Name: 111, dtype: object
# backer_info    {"backer_id": "sl474", "cf_id": 563, "name": "Sydney Louvet", "email": "slouvet@gmail.com"}
# Name: 112, dtype: object
# backer_info    {"backer_id": "dp154", "cf_id": 65, "name": "Dusty Paola", "email": "dpaola@outlook.com"}
# Name: 113, dtype: object
# backer_info    {"backer_id": "id770", "cf_id": 238, "name": "Ilario Dressler", "email": "idressler@protonmail.com"}
# Name: 114, dtype: object
# backer_info    {"backer_id": "ek669", "cf_id": 65, "name": "Emile Khan", "email": "ekhan@outlook.com"}
# Name: 115, dtype: object
# backer_info    {"backer_id": "eb945", "cf_id": 65, "name": "Elliot Bonomo", "email": "ebonomo@yandex.com"}
# Name: 116, dtype: object
# backer_info    {"backer_id": "ag917", "cf_id": 1114, "name": "Arvin Golden", "email": "agolden@yandex.com"}
# Name: 117, dtype: object
# backer_info    {"backer_id": "ac437", "cf_id": 563, "name": "Ampelio Cabrera", "email": "acabrera@live.com"}
# Name: 118, dtype: object
# backer_info    {"backer_id": "sf583", "cf_id": 1572, "name": "Somer Fuhrmann", "email": "sfuhrmann@yahoo.com"}
# Name: 119, dtype: object
# backer_info    {"backer_id": "sa973", "cf_id": 65, "name": "Shanti Allard", "email": "sallard@yandex.com"}
# Name: 120, dtype: object
# backer_info    {"backer_id": "kc836", "cf_id": 65, "name": "Konstanze Caroselli", "email": "kcaroselli@yandex.com"}
# Name: 121, dtype: object
# backer_info    {"backer_id": "bt844", "cf_id": 65, "name": "Bellarmine Taylor", "email": "btaylor@outlook.com"}
# Name: 122, dtype: object
# backer_info    {"backer_id": "mf392", "cf_id": 65, "name": "Matthew Fischer", "email": "mfischer@live.com"}
# Name: 123, dtype: object
# backer_info    {"backer_id": "dh568", "cf_id": 65, "name": "Dan Hoffmann", "email": "dhoffmann@yandex.com"}
# Name: 124, dtype: object
# backer_info    {"backer_id": "iv880", "cf_id": 968, "name": "Imelda Vallee", "email": "ivallee@gmail.com"}
# Name: 125, dtype: object
# backer_info    {"backer_id": "gl219", "cf_id": 1572, "name": "Giancarlo Lindsey", "email": "glindsey@protonmail.com"}
# Name: 126, dtype: object
# backer_info    {"backer_id": "kb890", "cf_id": 1572, "name": "Kris Brennan", "email": "kbrennan@protonmail.com"}
# Name: 127, dtype: object
# backer_info    {"backer_id": "jf901", "cf_id": 65, "name": "Johnnie Fux", "email": "jfux@gmail.com"}
# Name: 128, dtype: object
# backer_info    {"backer_id": "ja340", "cf_id": 1114, "name": "Janeth Adam", "email": "jadam@protonmail.com"}
# Name: 129, dtype: object
# backer_info    {"backer_id": "ar906", "cf_id": 65, "name": "Agata Rosa", "email": "arosa@yahoo.com"}
# Name: 130, dtype: object
# backer_info    {"backer_id": "dc579", "cf_id": 65, "name": "Dennise Cabrera", "email": "dcabrera@live.com"}
# Name: 131, dtype: object
# backer_info    {"backer_id": "gg660", "cf_id": 65, "name": "Garret Geier", "email": "ggeier@yahoo.com"}
# Name: 132, dtype: object
# backer_info    {"backer_id": "db112", "cf_id": 65, "name": "Delia Beguin", "email": "dbeguin@yandex.com"}
# Name: 133, dtype: object
# backer_info    {"backer_id": "ld487", "cf_id": 65, "name": "Louanne Damiani", "email": "ldamiani@outlook.com"}
# Name: 134, dtype: object
# backer_info    {"backer_id": "bj475", "cf_id": 1572, "name": "Bronze Jenkins", "email": "bjenkins@protonmail.com"}
# Name: 135, dtype: object
# backer_info    {"backer_id": "mc838", "cf_id": 65, "name": "Mila Coffey", "email": "mcoffey@protonmail.com"}
# Name: 136, dtype: object
# backer_info    {"backer_id": "he768", "cf_id": 65, "name": "Hank Essert", "email": "hessert@gmail.com"}
# Name: 137, dtype: object
# backer_info    {"backer_id": "pm973", "cf_id": 65, "name": "Paulina Marais", "email": "pmarais@protonmail.com"}
# Name: 138, dtype: object
# backer_info    {"backer_id": "bf986", "cf_id": 65, "name": "Beatrice Fulco", "email": "bfulco@gmail.com"}
# Name: 139, dtype: object
# backer_info    {"backer_id": "sb322", "cf_id": 65, "name": "Sudie Burgess", "email": "sburgess@yandex.com"}
# Name: 140, dtype: object
# backer_info    {"backer_id": "ps571", "cf_id": 563, "name": "Prince Suarez", "email": "psuarez@yahoo.com"}
# Name: 141, dtype: object
# backer_info    {"backer_id": "mb333", "cf_id": 1572, "name": "Mitzi Biermann", "email": "mbiermann@gmail.com"}
# Name: 142, dtype: object
# backer_info    {"backer_id": "ab290", "cf_id": 1572, "name": "Aminata Bru", "email": "abru@yahoo.com"}
# Name: 143, dtype: object
# backer_info    {"backer_id": "jm190", "cf_id": 968, "name": "Jina Magrino", "email": "jmagrino@live.com"}
# Name: 144, dtype: object
# backer_info    {"backer_id": "rg933", "cf_id": 65, "name": "Rosena Gould", "email": "rgould@gmail.com"}
# Name: 145, dtype: object
# backer_info    {"backer_id": "ik787", "cf_id": 1572, "name": "Issac Kline", "email": "ikline@live.com"}
# Name: 146, dtype: object
# backer_info    {"backer_id": "rl982", "cf_id": 65, "name": "Roderica Lehmann", "email": "rlehmann@gmail.com"}
# Name: 147, dtype: object
# backer_info    {"backer_id": "ac179", "cf_id": 65, "name": "Ariah Comte", "email": "acomte@yandex.com"}
# Name: 148, dtype: object
# backer_info    {"backer_id": "eg193", "cf_id": 238, "name": "Ellis Gamble", "email": "egamble@yahoo.com"}
# Name: 149, dtype: object
# backer_info    {"backer_id": "fl258", "cf_id": 65, "name": "Friedrich Lott", "email": "flott@yandex.com"}
# Name: 150, dtype: object
# backer_info    {"backer_id": "mb203", "cf_id": 1114, "name": "Marilou Beutel", "email": "mbeutel@gmail.com"}
# Name: 151, dtype: object
# backer_info    {"backer_id": "en399", "cf_id": 65, "name": "Elene Navarro", "email": "enavarro@yahoo.com"}
# Name: 152, dtype: object
# backer_info    {"backer_id": "mr756", "cf_id": 968, "name": "Mac Raffin", "email": "mraffin@yahoo.com"}
# Name: 153, dtype: object
# backer_info    {"backer_id": "sc271", "cf_id": 563, "name": "Shona Carr", "email": "scarr@outlook.com"}
# Name: 154, dtype: object
# backer_info    {"backer_id": "xg684", "cf_id": 1572, "name": "Ximena Guy", "email": "xguy@protonmail.com"}
# Name: 155, dtype: object
# backer_info    {"backer_id": "ab829", "cf_id": 563, "name": "Arnaud Becker", "email": "abecker@live.com"}
# Name: 156, dtype: object
# backer_info    {"backer_id": "fd404", "cf_id": 65, "name": "Fiore Desautels", "email": "fdesautels@live.com"}
# Name: 157, dtype: object
# backer_info    {"backer_id": "rm849", "cf_id": 563, "name": "Robby Mccray", "email": "rmccray@gmail.com"}
# Name: 158, dtype: object
# backer_info    {"backer_id": "lr658", "cf_id": 65, "name": "Louis Rush", "email": "lrush@protonmail.com"}
# Name: 159, dtype: object
# backer_info    {"backer_id": "sh994", "cf_id": 65, "name": "Serena Holzknecht", "email": "sholzknecht@protonmail.com"}
# Name: 160, dtype: object
# backer_info    {"backer_id": "zv654", "cf_id": 65, "name": "Zan Verdier", "email": "zverdier@yahoo.com"}
# Name: 161, dtype: object
# backer_info    {"backer_id": "hb861", "cf_id": 1572, "name": "Hipolito Baldocchi", "email": "hbaldocchi@gmail.com"}
# Name: 162, dtype: object
# backer_info    {"backer_id": "hb280", "cf_id": 65, "name": "Hollis Barnett", "email": "hbarnett@live.com"}
# Name: 163, dtype: object
# backer_info    {"backer_id": "be560", "cf_id": 65, "name": "Barend Edwards", "email": "bedwards@yandex.com"}
# Name: 164, dtype: object
# backer_info    {"backer_id": "lh820", "cf_id": 563, "name": "Loane Holst", "email": "lholst@live.com"}
# Name: 165, dtype: object
# backer_info    {"backer_id": "zp659", "cf_id": 1572, "name": "Zeno Pruneau", "email": "zpruneau@gmail.com"}
# Name: 166, dtype: object
# backer_info    {"backer_id": "de758", "cf_id": 1114, "name": "Devon Epifano", "email": "depifano@protonmail.com"}
# Name: 167, dtype: object
# backer_info    {"backer_id": "jb896", "cf_id": 65, "name": "Jarrett Barrera", "email": "jbarrera@gmail.com"}
# Name: 168, dtype: object
# backer_info    {"backer_id": "wb355", "cf_id": 238, "name": "Walburg Burris", "email": "wburris@outlook.com"}
# Name: 169, dtype: object
# backer_info    {"backer_id": "rd560", "cf_id": 65, "name": "Raffaela Darras", "email": "rdarras@gmail.com"}
# Name: 170, dtype: object
# backer_info    {"backer_id": "er574", "cf_id": 1572, "name": "Eli Resta", "email": "eresta@outlook.com"}
# Name: 171, dtype: object
# backer_info    {"backer_id": "jc163", "cf_id": 65, "name": "Jin Chen", "email": "jchen@outlook.com"}
# Name: 172, dtype: object
# backer_info    {"backer_id": "kb942", "cf_id": 1114, "name": "Katja Butler", "email": "kbutler@protonmail.com"}
# Name: 173, dtype: object
# backer_info    {"backer_id": "af969", "cf_id": 563, "name": "Allegra Fiedler", "email": "afiedler@yandex.com"}
# Name: 174, dtype: object
# backer_info    {"backer_id": "bp212", "cf_id": 1572, "name": "Benton Pereira", "email": "bpereira@live.com"}
# Name: 175, dtype: object
# backer_info    {"backer_id": "tc947", "cf_id": 65, "name": "Tesha Carpinello", "email": "tcarpinello@outlook.com"}
# Name: 176, dtype: object
# backer_info    {"backer_id": "ak106", "cf_id": 1572, "name": "Anneli Kaufman", "email": "akaufman@outlook.com"}
# Name: 177, dtype: object
# backer_info    {"backer_id": "mr294", "cf_id": 1572, "name": "Merle Rowe", "email": "mrowe@yahoo.com"}
# Name: 178, dtype: object
# backer_info    {"backer_id": "bb365", "cf_id": 65, "name": "Bev Bellotti", "email": "bbellotti@yandex.com"}
# Name: 179, dtype: object
# backer_info    {"backer_id": "bj274", "cf_id": 65, "name": "Blake Jenkins", "email": "bjenkins@outlook.com"}
# Name: 180, dtype: object
# backer_info    {"backer_id": "qw345", "cf_id": 1572, "name": "Qiana Washington", "email": "qwashington@gmail.com"}
# Name: 181, dtype: object
# backer_info    {"backer_id": "ra925", "cf_id": 65, "name": "Rayane Adam", "email": "radam@live.com"}
# Name: 182, dtype: object
# backer_info    {"backer_id": "pg824", "cf_id": 968, "name": "Petronella Guilbaud", "email": "pguilbaud@outlook.com"}
# Name: 183, dtype: object
# backer_info    {"backer_id": "ef414", "cf_id": 65, "name": "Elodia Forgione", "email": "eforgione@gmail.com"}
# Name: 184, dtype: object
# backer_info    {"backer_id": "rp650", "cf_id": 238, "name": "Ryan Potts", "email": "rpotts@protonmail.com"}
# Name: 185, dtype: object
# backer_info    {"backer_id": "se972", "cf_id": 1114, "name": "Sigmund Everett", "email": "severett@yahoo.com"}
# Name: 186, dtype: object
# backer_info    {"backer_id": "sd958", "cf_id": 65, "name": "Serafina Desroches", "email": "sdesroches@yahoo.com"}
# Name: 187, dtype: object
# backer_info    {"backer_id": "mb304", "cf_id": 65, "name": "Murray Barrese", "email": "mbarrese@yandex.com"}
# Name: 188, dtype: object
# backer_info    {"backer_id": "lr409", "cf_id": 563, "name": "Luis Roberts", "email": "lroberts@protonmail.com"}
# Name: 189, dtype: object
# backer_info    {"backer_id": "fm559", "cf_id": 65, "name": "Felicia Mcneil", "email": "fmcneil@outlook.com"}
# Name: 190, dtype: object
# backer_info    {"backer_id": "wd714", "cf_id": 65, "name": "Willette Dattoli", "email": "wdattoli@outlook.com"}
# Name: 191, dtype: object
# backer_info    {"backer_id": "ls638", "cf_id": 1572, "name": "Lucas Stephens", "email": "lstephens@protonmail.com"}
# Name: 192, dtype: object
# backer_info    {"backer_id": "am362", "cf_id": 65, "name": "Amo Moses", "email": "amoses@outlook.com"}
# Name: 193, dtype: object
# backer_info    {"backer_id": "ta190", "cf_id": 563, "name": "Tandy Acker", "email": "tacker@outlook.com"}
# Name: 194, dtype: object
# backer_info    {"backer_id": "rb753", "cf_id": 65, "name": "Rolf Biron", "email": "rbiron@outlook.com"}
# Name: 195, dtype: object
# backer_info    {"backer_id": "cc594", "cf_id": 65, "name": "Catharina Cappella", "email": "ccappella@gmail.com"}
# Name: 196, dtype: object
# backer_info    {"backer_id": "vh915", "cf_id": 65, "name": "Virgilio Hyde", "email": "vhyde@live.com"}
# Name: 197, dtype: object
# backer_info    {"backer_id": "og539", "cf_id": 65, "name": "Ollie Gwerder", "email": "ogwerder@yandex.com"}
# Name: 198, dtype: object
# backer_info    {"backer_id": "dd470", "cf_id": 1911, "name": "Daniela Demers", "email": "ddemers@yahoo.com"}
# Name: 199, dtype: object
# backer_info    {"backer_id": "ap718", "cf_id": 238, "name": "Angel Peragine", "email": "aperagine@live.com"}
# Name: 200, dtype: object
# backer_info    {"backer_id": "vw158", "cf_id": 1572, "name": "Vicenzo Wells", "email": "vwells@yandex.com"}
# Name: 201, dtype: object
# backer_info    {"backer_id": "fh696", "cf_id": 2284, "name": "Fernanda Hodges", "email": "fhodges@yandex.com"}
# Name: 202, dtype: object
# backer_info    {"backer_id": "df617", "cf_id": 968, "name": "Darrin Fiedler", "email": "dfiedler@yahoo.com"}
# Name: 203, dtype: object
# backer_info    {"backer_id": "jv716", "cf_id": 65, "name": "Janine Veronesi", "email": "jveronesi@gmail.com"}
# Name: 204, dtype: object
# backer_info    {"backer_id": "tc807", "cf_id": 65, "name": "Terenzio Carver", "email": "tcarver@gmail.com"}
# Name: 205, dtype: object
# backer_info    {"backer_id": "me460", "cf_id": 563, "name": "Magali Eilerts", "email": "meilerts@gmail.com"}
# Name: 206, dtype: object
# backer_info    {"backer_id": "kp942", "cf_id": 1572, "name": "Kimber Puech", "email": "kpuech@protonmail.com"}
# Name: 207, dtype: object
# backer_info    {"backer_id": "xp438", "cf_id": 563, "name": "Xenia Pergola", "email": "xpergola@yandex.com"}
# Name: 208, dtype: object
# backer_info    {"backer_id": "af564", "cf_id": 1572, "name": "Arlena Fox", "email": "afox@protonmail.com"}
# Name: 209, dtype: object
# backer_info    {"backer_id": "wn746", "cf_id": 1114, "name": "Wilfred Nazzaro", "email": "wnazzaro@yahoo.com"}
# Name: 210, dtype: object
# backer_info    {"backer_id": "ad641", "cf_id": 1572, "name": "Angelina Decker", "email": "adecker@yahoo.com"}
# Name: 211, dtype: object
# backer_info    {"backer_id": "rs660", "cf_id": 65, "name": "Ressie Schneider", "email": "rschneider@live.com"}
# Name: 212, dtype: object
# backer_info    {"backer_id": "dp520", "cf_id": 65, "name": "Daine Pruneau", "email": "dpruneau@outlook.com"}
# Name: 213, dtype: object
# backer_info    {"backer_id": "me520", "cf_id": 65, "name": "Marius Emilio", "email": "memilio@gmail.com"}
# Name: 214, dtype: object
# backer_info    {"backer_id": "es977", "cf_id": 1572, "name": "Emily Stout", "email": "estout@gmail.com"}
# Name: 215, dtype: object
# backer_info    {"backer_id": "sd883", "cf_id": 3138, "name": "Shaunna Dreher", "email": "sdreher@yahoo.com"}
# Name: 216, dtype: object
# backer_info    {"backer_id": "tb283", "cf_id": 65, "name": "Toi Briere", "email": "tbriere@outlook.com"}
# Name: 217, dtype: object
# backer_info    {"backer_id": "eb415", "cf_id": 65, "name": "Eliodoro Black", "email": "eblack@yahoo.com"}
# Name: 218, dtype: object
# backer_info    {"backer_id": "fb116", "cf_id": 1572, "name": "Faustino Burgstaller", "email": "fburgstaller@outlook.com"}
# Name: 219, dtype: object
# backer_info    {"backer_id": "jb391", "cf_id": 1572, "name": "Jeramy Benard", "email": "jbenard@yandex.com"}
# Name: 220, dtype: object
# backer_info    {"backer_id": "ac624", "cf_id": 563, "name": "Annika Curtis", "email": "acurtis@live.com"}
# Name: 221, dtype: object
# backer_info    {"backer_id": "kc104", "cf_id": 65, "name": "Kelia Campbell", "email": "kcampbell@protonmail.com"}
# Name: 222, dtype: object
# backer_info    {"backer_id": "dg582", "cf_id": 65, "name": "Dario Gerst", "email": "dgerst@protonmail.com"}
# Name: 223, dtype: object
# backer_info    {"backer_id": "mb933", "cf_id": 1572, "name": "Maryetta Bussa", "email": "mbussa@yahoo.com"}
# Name: 224, dtype: object
# backer_info    {"backer_id": "em898", "cf_id": 65, "name": "Emerich Mccoy", "email": "emccoy@live.com"}
# Name: 225, dtype: object
# backer_info    {"backer_id": "tw982", "cf_id": 968, "name": "Timothe Wilder", "email": "twilder@yandex.com"}
# Name: 226, dtype: object
# backer_info    {"backer_id": "ab575", "cf_id": 65, "name": "Amadore Breitbarth", "email": "abreitbarth@protonmail.com"}
# Name: 227, dtype: object
# backer_info    {"backer_id": "dg744", "cf_id": 1572, "name": "Dave Gaillard", "email": "dgaillard@live.com"}
# Name: 228, dtype: object
# backer_info    {"backer_id": "cj442", "cf_id": 1572, "name": "Catrin Joseph", "email": "cjoseph@live.com"}
# Name: 229, dtype: object
# backer_info    {"backer_id": "lo117", "cf_id": 65, "name": "Laverne Ortega", "email": "lortega@yandex.com"}
# Name: 230, dtype: object
# backer_info    {"backer_id": "bg270", "cf_id": 65, "name": "Bulah Guay", "email": "bguay@yandex.com"}
# Name: 231, dtype: object
# backer_info    {"backer_id": "jc692", "cf_id": 65, "name": "Jae Castellucci", "email": "jcastellucci@yahoo.com"}
# Name: 232, dtype: object
# backer_info    {"backer_id": "jf750", "cf_id": 1572, "name": "Joseph Freeman", "email": "jfreeman@live.com"}
# Name: 233, dtype: object
# backer_info    {"backer_id": "lr317", "cf_id": 968, "name": "Lena Robbins", "email": "lrobbins@live.com"}
# Name: 234, dtype: object
# backer_info    {"backer_id": "cp253", "cf_id": 65, "name": "Charley Petitjean", "email": "cpetitjean@yandex.com"}
# Name: 235, dtype: object
# backer_info    {"backer_id": "vv330", "cf_id": 65, "name": "Veronika Vesco", "email": "vvesco@live.com"}
# Name: 236, dtype: object
# backer_info    {"backer_id": "ch724", "cf_id": 1572, "name": "Calandra Hofmeister", "email": "chofmeister@protonmail.com"}
# Name: 237, dtype: object
# backer_info    {"backer_id": "dm121", "cf_id": 65, "name": "Devon Marques", "email": "dmarques@yandex.com"}
# Name: 238, dtype: object
# backer_info    {"backer_id": "lc141", "cf_id": 65, "name": "Leon Carson", "email": "lcarson@gmail.com"}
# Name: 239, dtype: object
# backer_info    {"backer_id": "am966", "cf_id": 65, "name": "Adelrico Meadows", "email": "ameadows@gmail.com"}
# Name: 240, dtype: object
# backer_info    {"backer_id": "ab249", "cf_id": 65, "name": "Adel Becke", "email": "abecke@yahoo.com"}
# Name: 241, dtype: object
# backer_info    {"backer_id": "mb828", "cf_id": 65, "name": "Mariya Babin", "email": "mbabin@outlook.com"}
# Name: 242, dtype: object
# backer_info    {"backer_id": "pu317", "cf_id": 65, "name": "Peg Urciuoli", "email": "purciuoli@yandex.com"}
# Name: 243, dtype: object
# backer_info    {"backer_id": "cb515", "cf_id": 1572, "name": "Clarita Barron", "email": "cbarron@protonmail.com"}
# Name: 244, dtype: object
# backer_info    {"backer_id": "so203", "cf_id": 563, "name": "Silvia Olson", "email": "solson@gmail.com"}
# Name: 245, dtype: object
# backer_info    {"backer_id": "aa284", "cf_id": 65, "name": "Armand Arnold", "email": "aarnold@live.com"}
# Name: 246, dtype: object
# backer_info    {"backer_id": "sc143", "cf_id": 65, "name": "Sueann Casciani", "email": "scasciani@outlook.com"}
# Name: 247, dtype: object
# backer_info    {"backer_id": "je217", "cf_id": 65, "name": "Jc Elliott", "email": "jelliott@yandex.com"}
# Name: 248, dtype: object
# backer_info    {"backer_id": "ke511", "cf_id": 1114, "name": "Kalet Eaton", "email": "keaton@outlook.com"}
# Name: 249, dtype: object
# backer_info    {"backer_id": "oa673", "cf_id": 563, "name": "Ottavia Abraham", "email": "oabraham@yandex.com"}
# Name: 250, dtype: object
# backer_info    {"backer_id": "sc432", "cf_id": 968, "name": "Swanhild Cameron", "email": "scameron@yandex.com"}
# Name: 251, dtype: object
# backer_info    {"backer_id": "aj655", "cf_id": 65, "name": "Alessandrina Jollenbeck", "email": "ajollenbeck@outlook.com"}
# Name: 252, dtype: object
# backer_info    {"backer_id": "jp351", "cf_id": 968, "name": "Jamison Perona", "email": "jperona@live.com"}
# Name: 253, dtype: object
# backer_info    {"backer_id": "lj758", "cf_id": 968, "name": "Louis Justice", "email": "ljustice@yahoo.com"}
# Name: 254, dtype: object
# backer_info    {"backer_id": "ps794", "cf_id": 1572, "name": "Pablo Sykes", "email": "psykes@yandex.com"}
# Name: 255, dtype: object
# backer_info    {"backer_id": "nb202", "cf_id": 1572, "name": "Nek Blecher", "email": "nblecher@yahoo.com"}
# Name: 256, dtype: object
# backer_info    {"backer_id": "gp356", "cf_id": 968, "name": "Guadalupe Pannone", "email": "gpannone@outlook.com"}
# Name: 257, dtype: object
# backer_info    {"backer_id": "rb945", "cf_id": 1572, "name": "Ramona Berg", "email": "rberg@yandex.com"}
# Name: 258, dtype: object
# backer_info    {"backer_id": "gw991", "cf_id": 65, "name": "Gioconda Webster", "email": "gwebster@live.com"}
# Name: 259, dtype: object
# backer_info    {"backer_id": "gb896", "cf_id": 910, "name": "George Bauers", "email": "gbauers@yahoo.com"}
# Name: 260, dtype: object
# backer_info    {"backer_id": "jm345", "cf_id": 563, "name": "Julian Maillot", "email": "jmaillot@yandex.com"}
# Name: 261, dtype: object
# backer_info    {"backer_id": "ma565", "cf_id": 1911, "name": "Melusina Asti", "email": "masti@yandex.com"}
# Name: 262, dtype: object
# backer_info    {"backer_id": "oh728", "cf_id": 65, "name": "Ornella Hester", "email": "ohester@live.com"}
# Name: 263, dtype: object
# backer_info    {"backer_id": "dg119", "cf_id": 1572, "name": "Dione Gass", "email": "dgass@yandex.com"}
# Name: 264, dtype: object
# backer_info    {"backer_id": "kd744", "cf_id": 968, "name": "Konrad Damone", "email": "kdamone@yandex.com"}
# Name: 265, dtype: object
# backer_info    {"backer_id": "ww138", "cf_id": 65, "name": "Walid Woods", "email": "wwoods@protonmail.com"}
# Name: 266, dtype: object
# backer_info    {"backer_id": "gb135", "cf_id": 1572, "name": "Giana Blevins", "email": "gblevins@protonmail.com"}
# Name: 267, dtype: object
# backer_info    {"backer_id": "lp541", "cf_id": 563, "name": "Lino Pires", "email": "lpires@yandex.com"}
# Name: 268, dtype: object
# backer_info    {"backer_id": "hm752", "cf_id": 65, "name": "Helmina Mosco", "email": "hmosco@outlook.com"}
# Name: 269, dtype: object
# backer_info    {"backer_id": "ib452", "cf_id": 1911, "name": "Inaya Barton", "email": "ibarton@yandex.com"}
# Name: 270, dtype: object
# backer_info    {"backer_id": "fc303", "cf_id": 65, "name": "Francesca Chambers", "email": "fchambers@protonmail.com"}
# Name: 271, dtype: object
# backer_info    {"backer_id": "kb141", "cf_id": 1114, "name": "Kenisha Bergfalk", "email": "kbergfalk@outlook.com"}
# Name: 272, dtype: object
# backer_info    {"backer_id": "is909", "cf_id": 65, "name": "Ismael Sarrazin", "email": "isarrazin@live.com"}
# Name: 273, dtype: object
# backer_info    {"backer_id": "hv133", "cf_id": 968, "name": "Holger Vitiello", "email": "hvitiello@protonmail.com"}
# Name: 274, dtype: object
# backer_info    {"backer_id": "nm163", "cf_id": 65, "name": "Nayla Melendez", "email": "nmelendez@yahoo.com"}
# Name: 275, dtype: object
# backer_info    {"backer_id": "cs899", "cf_id": 65, "name": "Camila Sciarretta", "email": "csciarretta@yandex.com"}
# Name: 276, dtype: object
# backer_info    {"backer_id": "lh190", "cf_id": 65, "name": "Lucia Hatfield", "email": "lhatfield@gmail.com"}
# Name: 277, dtype: object
# backer_info    {"backer_id": "as260", "cf_id": 65, "name": "Annetta Scholz", "email": "ascholz@live.com"}
# Name: 278, dtype: object
# backer_info    {"backer_id": "db149", "cf_id": 65, "name": "Demarcus Barthelemy", "email": "dbarthelemy@gmail.com"}
# Name: 279, dtype: object
# backer_info    {"backer_id": "cg952", "cf_id": 563, "name": "Clifton Garibaldi", "email": "cgaribaldi@live.com"}
# Name: 280, dtype: object
# backer_info    {"backer_id": "tm490", "cf_id": 65, "name": "Tobias Mcintyre", "email": "tmcintyre@gmail.com"}
# Name: 281, dtype: object
# backer_info    {"backer_id": "lt569", "cf_id": 65, "name": "Lalie Tyler", "email": "ltyler@outlook.com"}
# Name: 282, dtype: object
# backer_info    {"backer_id": "ce212", "cf_id": 65, "name": "Cristiano Everhart", "email": "ceverhart@yandex.com"}
# Name: 283, dtype: object
# backer_info    {"backer_id": "sr285", "cf_id": 2284, "name": "Shirl Rochon", "email": "srochon@live.com"}
# Name: 284, dtype: object
# backer_info    {"backer_id": "tc231", "cf_id": 2882, "name": "Treena Ciampa", "email": "tciampa@yandex.com"}
# Name: 285, dtype: object
# backer_info    {"backer_id": "ll471", "cf_id": 968, "name": "Luther Leonard", "email": "lleonard@gmail.com"}
# Name: 286, dtype: object
# backer_info    {"backer_id": "aa130", "cf_id": 65, "name": "Affonso Abraham", "email": "aabraham@outlook.com"}
# Name: 287, dtype: object
# backer_info    {"backer_id": "sb241", "cf_id": 563, "name": "So Boilard", "email": "sboilard@yandex.com"}
# Name: 288, dtype: object
# backer_info    {"backer_id": "lb909", "cf_id": 968, "name": "Luther Barberi", "email": "lbarberi@yahoo.com"}
# Name: 289, dtype: object
# backer_info    {"backer_id": "lw976", "cf_id": 910, "name": "Leuther Webb", "email": "lwebb@gmail.com"}
# Name: 290, dtype: object
# backer_info    {"backer_id": "ab143", "cf_id": 1114, "name": "Abel Burke", "email": "aburke@outlook.com"}
# Name: 291, dtype: object
# backer_info    {"backer_id": "cg893", "cf_id": 65, "name": "Calogero Geiger", "email": "cgeiger@outlook.com"}
# Name: 292, dtype: object
# backer_info    {"backer_id": "nl492", "cf_id": 65, "name": "Nelson Lemire", "email": "nlemire@yahoo.com"}
# Name: 293, dtype: object
# backer_info    {"backer_id": "nc285", "cf_id": 1572, "name": "Nadene Cartelli", "email": "ncartelli@live.com"}
# Name: 294, dtype: object
# backer_info    {"backer_id": "ct703", "cf_id": 65, "name": "Calvin Tate", "email": "ctate@yandex.com"}
# Name: 295, dtype: object
# backer_info    {"backer_id": "aw876", "cf_id": 1572, "name": "Axel Watts", "email": "awatts@protonmail.com"}
# Name: 296, dtype: object
# backer_info    {"backer_id": "af506", "cf_id": 563, "name": "Alda Feigenbaum", "email": "afeigenbaum@live.com"}
# Name: 297, dtype: object
# backer_info    {"backer_id": "es282", "cf_id": 65, "name": "Elena Shields", "email": "eshields@outlook.com"}
# Name: 298, dtype: object
# backer_info    {"backer_id": "co633", "cf_id": 65, "name": "Circinus Odom", "email": "codom@yahoo.com"}
# Name: 299, dtype: object
# backer_info    {"backer_id": "mh163", "cf_id": 65, "name": "Marietta Holzmann", "email": "mholzmann@yandex.com"}
# Name: 300, dtype: object
# backer_info    {"backer_id": "pc978", "cf_id": 65, "name": "Peg Corriveau", "email": "pcorriveau@protonmail.com"}
# Name: 301, dtype: object
# backer_info    {"backer_id": "gc386", "cf_id": 2882, "name": "Gregory Cianciolo", "email": "gcianciolo@live.com"}
# Name: 302, dtype: object
# backer_info    {"backer_id": "nl252", "cf_id": 1114, "name": "Nolhan Lindsey", "email": "nlindsey@live.com"}
# Name: 303, dtype: object
# backer_info    {"backer_id": "rb829", "cf_id": 1572, "name": "Romero Blau", "email": "rblau@gmail.com"}
# Name: 304, dtype: object
# backer_info    {"backer_id": "gl884", "cf_id": 65, "name": "Genaro Larose", "email": "glarose@yahoo.com"}
# Name: 305, dtype: object
# backer_info    {"backer_id": "og404", "cf_id": 65, "name": "Oralee Garbarino", "email": "ogarbarino@live.com"}
# Name: 306, dtype: object
# backer_info    {"backer_id": "kr745", "cf_id": 1911, "name": "Karsten Riggs", "email": "kriggs@live.com"}
# Name: 307, dtype: object
# backer_info    {"backer_id": "jc104", "cf_id": 238, "name": "Joris Cline", "email": "jcline@yandex.com"}
# Name: 308, dtype: object
# backer_info    {"backer_id": "th958", "cf_id": 968, "name": "Tasha Holzknecht", "email": "tholzknecht@live.com"}
# Name: 309, dtype: object
# backer_info    {"backer_id": "jb207", "cf_id": 65, "name": "Jarrett Beaumont", "email": "jbeaumont@yandex.com"}
# Name: 310, dtype: object
# backer_info    {"backer_id": "lm386", "cf_id": 65, "name": "Laverne Maddalone", "email": "lmaddalone@yahoo.com"}
# Name: 311, dtype: object
# backer_info    {"backer_id": "ic277", "cf_id": 968, "name": "Imre Carlson", "email": "icarlson@live.com"}
# Name: 312, dtype: object
# backer_info    {"backer_id": "ab714", "cf_id": 968, "name": "Angel Brennan", "email": "abrennan@live.com"}
# Name: 313, dtype: object
# backer_info    {"backer_id": "jm813", "cf_id": 2488, "name": "Jinny Michaud", "email": "jmichaud@live.com"}
# Name: 314, dtype: object
# backer_info    {"backer_id": "ma226", "cf_id": 238, "name": "Maryam Armellino", "email": "marmellino@outlook.com"}
# Name: 315, dtype: object
# backer_info    {"backer_id": "lm154", "cf_id": 1114, "name": "Lyle Massey", "email": "lmassey@yandex.com"}
# Name: 316, dtype: object
# backer_info    {"backer_id": "pp209", "cf_id": 65, "name": "Peppe Pohl", "email": "ppohl@gmail.com"}
# Name: 317, dtype: object
# backer_info    {"backer_id": "ss320", "cf_id": 1114, "name": "Shakita Sabatier", "email": "ssabatier@gmail.com"}
# Name: 318, dtype: object
# backer_info    {"backer_id": "lb805", "cf_id": 1572, "name": "Lynwood Bozza", "email": "lbozza@yahoo.com"}
# Name: 319, dtype: object
# backer_info    {"backer_id": "sf196", "cf_id": 968, "name": "Siglinde Flores", "email": "sflores@live.com"}
# Name: 320, dtype: object
# backer_info    {"backer_id": "jc350", "cf_id": 1572, "name": "Jaden Castro", "email": "jcastro@outlook.com"}
# Name: 321, dtype: object
# backer_info    {"backer_id": "bh958", "cf_id": 1114, "name": "Bartolo Haupt", "email": "bhaupt@outlook.com"}
# Name: 322, dtype: object
# backer_info    {"backer_id": "vp800", "cf_id": 65, "name": "Venetta Perugini", "email": "vperugini@gmail.com"}
# Name: 323, dtype: object
# backer_info    {"backer_id": "ec148", "cf_id": 1572, "name": "Ellsworth Clements", "email": "eclements@yahoo.com"}
# Name: 324, dtype: object
# backer_info    {"backer_id": "ha431", "cf_id": 65, "name": "Harbin Alston", "email": "halston@outlook.com"}
# Name: 325, dtype: object
# backer_info    {"backer_id": "sw972", "cf_id": 65, "name": "Syrine Walter", "email": "swalter@yahoo.com"}
# Name: 326, dtype: object
# backer_info    {"backer_id": "sb891", "cf_id": 1572, "name": "Sansone Bisaillon", "email": "sbisaillon@protonmail.com"}
# Name: 327, dtype: object
# backer_info    {"backer_id": "sf735", "cf_id": 1114, "name": "Shantay Fiori", "email": "sfiori@protonmail.com"}
# Name: 328, dtype: object
# backer_info    {"backer_id": "mp538", "cf_id": 563, "name": "Mary Prince", "email": "mprince@protonmail.com"}
# Name: 329, dtype: object
# backer_info    {"backer_id": "cf904", "cf_id": 1572, "name": "Catrin Ferguson", "email": "cferguson@gmail.com"}
# Name: 330, dtype: object
# backer_info    {"backer_id": "gs818", "cf_id": 1572, "name": "Gianpiero Samson", "email": "gsamson@yandex.com"}
# Name: 331, dtype: object
# backer_info    {"backer_id": "ra782", "cf_id": 1572, "name": "Robert Altieri", "email": "raltieri@protonmail.com"}
# Name: 332, dtype: object
# backer_info    {"backer_id": "yc752", "cf_id": 1911, "name": "Yvone Capodanno", "email": "ycapodanno@live.com"}
# Name: 333, dtype: object
# backer_info    {"backer_id": "le377", "cf_id": 563, "name": "Lucetta Eichel", "email": "leichel@protonmail.com"}
# Name: 334, dtype: object
# backer_info    {"backer_id": "ja139", "cf_id": 968, "name": "Jalisa Anastasi", "email": "janastasi@yandex.com"}
# Name: 335, dtype: object
# backer_info    {"backer_id": "jf881", "cf_id": 65, "name": "Jessi Farley", "email": "jfarley@yahoo.com"}
# Name: 336, dtype: object
# backer_info    {"backer_id": "am638", "cf_id": 1114, "name": "Adolph Merrill", "email": "amerrill@gmail.com"}
# Name: 337, dtype: object
# backer_info    {"backer_id": "rh663", "cf_id": 65, "name": "Riyad Holst", "email": "rholst@outlook.com"}
# Name: 338, dtype: object
# backer_info    {"backer_id": "dl438", "cf_id": 238, "name": "Donatien Lefrancois", "email": "dlefrancois@yandex.com"}
# Name: 339, dtype: object
# backer_info    {"backer_id": "je184", "cf_id": 1114, "name": "Jere Evans", "email": "jevans@outlook.com"}
# Name: 340, dtype: object
# backer_info    {"backer_id": "xg938", "cf_id": 65, "name": "Xandi Glenn", "email": "xglenn@live.com"}
# Name: 341, dtype: object
# backer_info    {"backer_id": "mg208", "cf_id": 563, "name": "Marianne Geiger", "email": "mgeiger@outlook.com"}
# Name: 342, dtype: object
# backer_info    {"backer_id": "ag672", "cf_id": 65, "name": "Alonzo Gautier", "email": "agautier@protonmail.com"}
# Name: 343, dtype: object
# backer_info    {"backer_id": "sc991", "cf_id": 65, "name": "Santo Cornacchia", "email": "scornacchia@yahoo.com"}
# Name: 344, dtype: object
# backer_info    {"backer_id": "ar456", "cf_id": 238, "name": "Aleida Robertson", "email": "arobertson@yahoo.com"}
# Name: 345, dtype: object
# backer_info    {"backer_id": "an122", "cf_id": 65, "name": "Alexandra Nolan", "email": "anolan@yandex.com"}
# Name: 346, dtype: object
# backer_info    {"backer_id": "mh749", "cf_id": 65, "name": "Marina Habich", "email": "mhabich@protonmail.com"}
# Name: 347, dtype: object
# backer_info    {"backer_id": "ac765", "cf_id": 65, "name": "Agnella Cloutier", "email": "acloutier@yahoo.com"}
# Name: 348, dtype: object
# backer_info    {"backer_id": "ln560", "cf_id": 563, "name": "Loralee Nerone", "email": "lnerone@live.com"}
# Name: 349, dtype: object
# backer_info    {"backer_id": "dm881", "cf_id": 1114, "name": "Dot Moore", "email": "dmoore@protonmail.com"}
# Name: 350, dtype: object
# backer_info    {"backer_id": "wm699", "cf_id": 65, "name": "Wolf Morin", "email": "wmorin@gmail.com"}
# Name: 351, dtype: object
# backer_info    {"backer_id": "ca628", "cf_id": 1114, "name": "Ciel Augustin", "email": "caugustin@yandex.com"}
# Name: 352, dtype: object
# backer_info    {"backer_id": "ls538", "cf_id": 1114, "name": "Leontina Saucier", "email": "lsaucier@live.com"}
# Name: 353, dtype: object
# backer_info    {"backer_id": "kr958", "cf_id": 563, "name": "Kathern Rodriquez", "email": "krodriquez@live.com"}
# Name: 354, dtype: object
# backer_info    {"backer_id": "ad265", "cf_id": 65, "name": "Alder Dressler", "email": "adressler@outlook.com"}
# Name: 355, dtype: object
# backer_info    {"backer_id": "am627", "cf_id": 1572, "name": "Aroghetto Manza", "email": "amanza@yahoo.com"}
# Name: 356, dtype: object
# backer_info    {"backer_id": "rp666", "cf_id": 1572, "name": "Roberto Perry", "email": "rperry@gmail.com"}
# Name: 357, dtype: object
# backer_info    {"backer_id": "rs221", "cf_id": 65, "name": "Reena Shaw", "email": "rshaw@protonmail.com"}
# Name: 358, dtype: object
# backer_info    {"backer_id": "ma490", "cf_id": 65, "name": "Melina Abeln", "email": "mabeln@yandex.com"}
# Name: 359, dtype: object
# ...
# Name: 5211, dtype: object
# backer_info    {"backer_id": "hc489", "cf_id": 1114, "name": "Hubert Cesaro", "email": "hcesaro@gmail.com"}
# Name: 5212, dtype: object
# backer_info    {"backer_id": "lw446", "cf_id": 65, "name": "Leni Whitehead", "email": "lwhitehead@yandex.com"}
# Name: 5213, dtype: object
# backer_info    {"backer_id": "ib653", "cf_id": 65, "name": "Ilan Brodbeck", "email": "ibrodbeck@gmail.com"}
# Name: 5214, dtype: object
# backer_info    {"backer_id": "oc280", "cf_id": 563, "name": "Ortensia Cochet", "email": "ocochet@protonmail.com"}
# Name: 5215, dtype: object
# backer_info    {"backer_id": "lc284", "cf_id": 65, "name": "Luci Carson", "email": "lcarson@yahoo.com"}
# Name: 5216, dtype: object
# backer_info    {"backer_id": "hw781", "cf_id": 563, "name": "Hanne Washington", "email": "hwashington@yahoo.com"}
# Name: 5217, dtype: object
# backer_info    {"backer_id": "ah818", "cf_id": 65, "name": "Adel Hoefler", "email": "ahoefler@yahoo.com"}
# Name: 5218, dtype: object
# backer_info    {"backer_id": "nf450", "cf_id": 563, "name": "Norma Fafard", "email": "nfafard@yandex.com"}
# Name: 5219, dtype: object
# backer_info    {"backer_id": "ov394", "cf_id": 65, "name": "Oscar Vescovi", "email": "ovescovi@yahoo.com"}
# Name: 5220, dtype: object
# backer_info    {"backer_id": "jg369", "cf_id": 1911, "name": "Jerry Gaines", "email": "jgaines@live.com"}
# Name: 5221, dtype: object
# backer_info    {"backer_id": "fc238", "cf_id": 563, "name": "Fanny Chavez", "email": "fchavez@yahoo.com"}
# Name: 5222, dtype: object
# backer_info    {"backer_id": "fh122", "cf_id": 1572, "name": "Fabron Hofmeister", "email": "fhofmeister@yandex.com"}
# Name: 5223, dtype: object
# backer_info    {"backer_id": "bd392", "cf_id": 563, "name": "Braulio Dion", "email": "bdion@outlook.com"}
# Name: 5224, dtype: object
# backer_info    {"backer_id": "cu924", "cf_id": 1572, "name": "Chong Urso", "email": "curso@gmail.com"}
# Name: 5225, dtype: object
# backer_info    {"backer_id": "mt575", "cf_id": 65, "name": "Madison Torres", "email": "mtorres@outlook.com"}
# Name: 5226, dtype: object
# backer_info    {"backer_id": "km250", "cf_id": 1114, "name": "Kevin Merritt", "email": "kmerritt@live.com"}
# Name: 5227, dtype: object
# backer_info    {"backer_id": "sb733", "cf_id": 563, "name": "Scevola Beckert", "email": "sbeckert@gmail.com"}
# Name: 5228, dtype: object
# backer_info    {"backer_id": "km480", "cf_id": 238, "name": "Kerstin Munier", "email": "kmunier@protonmail.com"}
# Name: 5229, dtype: object
# backer_info    {"backer_id": "fc499", "cf_id": 968, "name": "Frederick Cianflone", "email": "fcianflone@live.com"}
# Name: 5230, dtype: object
# backer_info    {"backer_id": "pb105", "cf_id": 2488, "name": "Patrick Bell", "email": "pbell@gmail.com"}
# Name: 5231, dtype: object
# backer_info    {"backer_id": "ah460", "cf_id": 910, "name": "Ali Hammond", "email": "ahammond@protonmail.com"}
# Name: 5232, dtype: object
# backer_info    {"backer_id": "jb408", "cf_id": 65, "name": "Julietta Bumgarner", "email": "jbumgarner@yandex.com"}
# Name: 5233, dtype: object
# backer_info    {"backer_id": "gh847", "cf_id": 238, "name": "Gabriella Hubbard", "email": "ghubbard@protonmail.com"}
# Name: 5234, dtype: object
# backer_info    {"backer_id": "dh151", "cf_id": 563, "name": "Dantae Herzog", "email": "dherzog@gmail.com"}
# Name: 5235, dtype: object
# backer_info    {"backer_id": "ep138", "cf_id": 65, "name": "Edison Payette", "email": "epayette@gmail.com"}
# Name: 5236, dtype: object
# backer_info    {"backer_id": "re139", "cf_id": 1114, "name": "Robbie Estes", "email": "restes@outlook.com"}
# Name: 5237, dtype: object
# backer_info    {"backer_id": "vh384", "cf_id": 968, "name": "Vitalian Herzog", "email": "vherzog@protonmail.com"}
# Name: 5238, dtype: object
# backer_info    {"backer_id": "hd759", "cf_id": 65, "name": "Harlan Dussault", "email": "hdussault@outlook.com"}
# Name: 5239, dtype: object
# backer_info    {"backer_id": "pc730", "cf_id": 65, "name": "Pamula Celani", "email": "pcelani@outlook.com"}
# Name: 5240, dtype: object
# backer_info    {"backer_id": "hc399", "cf_id": 563, "name": "Hansel Collier", "email": "hcollier@live.com"}
# Name: 5241, dtype: object
# backer_info    {"backer_id": "kh469", "cf_id": 65, "name": "Kelya Huff", "email": "khuff@yandex.com"}
# Name: 5242, dtype: object
# backer_info    {"backer_id": "ak547", "cf_id": 1572, "name": "Airiana Koch", "email": "akoch@gmail.com"}
# Name: 5243, dtype: object
# backer_info    {"backer_id": "kl381", "cf_id": 1572, "name": "Keli Lemieux", "email": "klemieux@live.com"}
# Name: 5244, dtype: object
# backer_info    {"backer_id": "mh122", "cf_id": 65, "name": "Maily Holman", "email": "mholman@live.com"}
# Name: 5245, dtype: object
# backer_info    {"backer_id": "jk709", "cf_id": 65, "name": "Juliet Keller", "email": "jkeller@yahoo.com"}
# Name: 5246, dtype: object
# backer_info    {"backer_id": "nl616", "cf_id": 1572, "name": "Nia Leccese", "email": "nleccese@protonmail.com"}
# Name: 5247, dtype: object
# backer_info    {"backer_id": "il493", "cf_id": 968, "name": "Ilyas Love", "email": "ilove@protonmail.com"}
# Name: 5248, dtype: object
# backer_info    {"backer_id": "ad891", "cf_id": 563, "name": "Anastagio Diefenbach", "email": "adiefenbach@yandex.com"}
# Name: 5249, dtype: object
# backer_info    {"backer_id": "ta728", "cf_id": 1572, "name": "Timmy Alston", "email": "talston@yandex.com"}
# Name: 5250, dtype: object
# backer_info    {"backer_id": "je334", "cf_id": 563, "name": "Jannike Erickson", "email": "jerickson@live.com"}
# Name: 5251, dtype: object
# backer_info    {"backer_id": "yb752", "cf_id": 1572, "name": "Yaelle Beck", "email": "ybeck@outlook.com"}
# Name: 5252, dtype: object
# backer_info    {"backer_id": "ad828", "cf_id": 1572, "name": "Andino Dupond", "email": "adupond@protonmail.com"}
# Name: 5253, dtype: object
# backer_info    {"backer_id": "ms902", "cf_id": 65, "name": "Marcellus Shepherd", "email": "mshepherd@yandex.com"}
# Name: 5254, dtype: object
# backer_info    {"backer_id": "mw265", "cf_id": 968, "name": "Marlene Winter", "email": "mwinter@yahoo.com"}
# Name: 5255, dtype: object
# backer_info    {"backer_id": "ad182", "cf_id": 563, "name": "Aaron Duriez", "email": "aduriez@gmail.com"}
# Name: 5256, dtype: object
# backer_info    {"backer_id": "rb998", "cf_id": 563, "name": "Rosa Biviano", "email": "rbiviano@gmail.com"}
# Name: 5257, dtype: object
# backer_info    {"backer_id": "cw620", "cf_id": 1572, "name": "Cristie Watts", "email": "cwatts@live.com"}
# Name: 5258, dtype: object
# backer_info    {"backer_id": "oe384", "cf_id": 65, "name": "Osvaldo Everett", "email": "oeverett@live.com"}
# Name: 5259, dtype: object
# backer_info    {"backer_id": "nh945", "cf_id": 563, "name": "Nivaldo Hofer", "email": "nhofer@yandex.com"}
# Name: 5260, dtype: object
# backer_info    {"backer_id": "mm661", "cf_id": 1572, "name": "Maia Michaud", "email": "mmichaud@yahoo.com"}
# Name: 5261, dtype: object
# backer_info    {"backer_id": "bc205", "cf_id": 563, "name": "Bella Corsentino", "email": "bcorsentino@gmail.com"}
# Name: 5262, dtype: object
# backer_info    {"backer_id": "tf224", "cf_id": 65, "name": "Tandra Frederick", "email": "tfrederick@live.com"}
# Name: 5263, dtype: object
# backer_info    {"backer_id": "al921", "cf_id": 1572, "name": "Antwan Lang", "email": "alang@outlook.com"}
# Name: 5264, dtype: object
# backer_info    {"backer_id": "wp850", "cf_id": 968, "name": "Wernher Pinsonneault", "email": "wpinsonneault@protonmail.com"}
# Name: 5265, dtype: object
# backer_info    {"backer_id": "ii934", "cf_id": 1572, "name": "Imran Iacovone", "email": "iiacovone@protonmail.com"}
# Name: 5266, dtype: object
# backer_info    {"backer_id": "sb352", "cf_id": 563, "name": "Santa Bernard", "email": "sbernard@live.com"}
# Name: 5267, dtype: object
# backer_info    {"backer_id": "tm685", "cf_id": 65, "name": "Tran Mccarty", "email": "tmccarty@gmail.com"}
# Name: 5268, dtype: object
# backer_info    {"backer_id": "rh260", "cf_id": 65, "name": "Rheba Heppenheimer", "email": "rheppenheimer@yandex.com"}
# Name: 5269, dtype: object
# backer_info    {"backer_id": "ic358", "cf_id": 1572, "name": "Ivette Camporeale", "email": "icamporeale@outlook.com"}
# Name: 5270, dtype: object
# backer_info    {"backer_id": "cm218", "cf_id": 1114, "name": "Cirrillo Mcdaniel", "email": "cmcdaniel@live.com"}
# Name: 5271, dtype: object
# backer_info    {"backer_id": "jf440", "cf_id": 1572, "name": "Jarred Fields", "email": "jfields@outlook.com"}
# Name: 5272, dtype: object
# backer_info    {"backer_id": "lh662", "cf_id": 968, "name": "Leonel Harman", "email": "lharman@outlook.com"}
# Name: 5273, dtype: object
# backer_info    {"backer_id": "ej298", "cf_id": 1572, "name": "Edmund Jacques", "email": "ejacques@outlook.com"}
# Name: 5274, dtype: object
# backer_info    {"backer_id": "cf305", "cf_id": 65, "name": "Campbell Fantin", "email": "cfantin@yandex.com"}
# Name: 5275, dtype: object
# backer_info    {"backer_id": "fm836", "cf_id": 65, "name": "Fiamma Mcclain", "email": "fmcclain@yandex.com"}
# Name: 5276, dtype: object
# backer_info    {"backer_id": "ma767", "cf_id": 1572, "name": "Manual Alston", "email": "malston@protonmail.com"}
# Name: 5277, dtype: object
# backer_info    {"backer_id": "fa720", "cf_id": 968, "name": "Frederica Albrecht", "email": "falbrecht@yahoo.com"}
# Name: 5278, dtype: object
# backer_info    {"backer_id": "ad310", "cf_id": 65, "name": "Adalgiso Davis", "email": "adavis@gmail.com"}
# Name: 5279, dtype: object
# backer_info    {"backer_id": "da148", "cf_id": 65, "name": "Devona Alston", "email": "dalston@yahoo.com"}
# Name: 5280, dtype: object
# backer_info    {"backer_id": "cf236", "cf_id": 1572, "name": "Claudia Foulon", "email": "cfoulon@yahoo.com"}
# Name: 5281, dtype: object
# backer_info    {"backer_id": "pw780", "cf_id": 65, "name": "Patience Walters", "email": "pwalters@yandex.com"}
# Name: 5282, dtype: object
# backer_info    {"backer_id": "js111", "cf_id": 65, "name": "Jonah Steele", "email": "jsteele@yandex.com"}
# Name: 5283, dtype: object
# backer_info    {"backer_id": "lb971", "cf_id": 1572, "name": "Luger Buchholz", "email": "lbuchholz@outlook.com"}
# Name: 5284, dtype: object
# backer_info    {"backer_id": "np634", "cf_id": 948, "name": "Noham Parisot", "email": "nparisot@live.com"}
# Name: 5285, dtype: object
# backer_info    {"backer_id": "wa263", "cf_id": 1114, "name": "Warner Acevedo", "email": "wacevedo@yandex.com"}
# Name: 5286, dtype: object
# backer_info    {"backer_id": "uc902", "cf_id": 563, "name": "Ulysses Carroll", "email": "ucarroll@outlook.com"}
# Name: 5287, dtype: object
# backer_info    {"backer_id": "ds679", "cf_id": 65, "name": "Donald Schneider", "email": "dschneider@yahoo.com"}
# Name: 5288, dtype: object
# backer_info    {"backer_id": "jl865", "cf_id": 65, "name": "Jawad Levac", "email": "jlevac@live.com"}
# Name: 5289, dtype: object
# backer_info    {"backer_id": "dl806", "cf_id": 65, "name": "Desiderio Lupoli", "email": "dlupoli@protonmail.com"}
# Name: 5290, dtype: object
# backer_info    {"backer_id": "ds938", "cf_id": 1572, "name": "Delinda Stanton", "email": "dstanton@outlook.com"}
# Name: 5291, dtype: object
# backer_info    {"backer_id": "wa639", "cf_id": 65, "name": "Waltraud Arnold", "email": "warnold@gmail.com"}
# Name: 5292, dtype: object
# backer_info    {"backer_id": "nc217", "cf_id": 65, "name": "Nero Cummings", "email": "ncummings@gmail.com"}
# Name: 5293, dtype: object
# backer_info    {"backer_id": "wr406", "cf_id": 65, "name": "Wynell Rodgers", "email": "wrodgers@yandex.com"}
# Name: 5294, dtype: object
# backer_info    {"backer_id": "ll189", "cf_id": 1572, "name": "Lou Lafont", "email": "llafont@outlook.com"}
# Name: 5295, dtype: object
# backer_info    {"backer_id": "jh181", "cf_id": 968, "name": "Joey Hodge", "email": "jhodge@live.com"}
# Name: 5296, dtype: object
# backer_info    {"backer_id": "af551", "cf_id": 65, "name": "Annice Fischer", "email": "afischer@gmail.com"}
# Name: 5297, dtype: object
# backer_info    {"backer_id": "fs278", "cf_id": 65, "name": "Florentine Schulz", "email": "fschulz@outlook.com"}
# Name: 5298, dtype: object
# backer_info    {"backer_id": "cb349", "cf_id": 238, "name": "Ciro Balla", "email": "cballa@gmail.com"}
# Name: 5299, dtype: object
# backer_info    {"backer_id": "cf235", "cf_id": 65, "name": "Carol Fields", "email": "cfields@gmail.com"}
# Name: 5300, dtype: object
# backer_info    {"backer_id": "eh161", "cf_id": 65, "name": "Emmie Harvey", "email": "eharvey@yandex.com"}
# Name: 5301, dtype: object
# backer_info    {"backer_id": "wh498", "cf_id": 2284, "name": "Walburg Heintze", "email": "wheintze@gmail.com"}
# Name: 5302, dtype: object
# backer_info    {"backer_id": "tp853", "cf_id": 1911, "name": "Tidiane Portier", "email": "tportier@yahoo.com"}
# Name: 5303, dtype: object
# backer_info    {"backer_id": "ab397", "cf_id": 563, "name": "Angelico Bonello", "email": "abonello@protonmail.com"}
# Name: 5304, dtype: object
# backer_info    {"backer_id": "ks860", "cf_id": 563, "name": "Kent Swanson", "email": "kswanson@protonmail.com"}
# Name: 5305, dtype: object
# backer_info    {"backer_id": "eb800", "cf_id": 1572, "name": "Edith Behrend", "email": "ebehrend@protonmail.com"}
# Name: 5306, dtype: object
# backer_info    {"backer_id": "ml240", "cf_id": 65, "name": "Merane Lehoux", "email": "mlehoux@yahoo.com"}
# Name: 5307, dtype: object
# backer_info    {"backer_id": "cd683", "cf_id": 563, "name": "Calandra Dato", "email": "cdato@yandex.com"}
# Name: 5308, dtype: object
# backer_info    {"backer_id": "fc562", "cf_id": 65, "name": "Felipe Carver", "email": "fcarver@outlook.com"}
# Name: 5309, dtype: object
# backer_info    {"backer_id": "lr795", "cf_id": 1114, "name": "Lou Riverin", "email": "lriverin@yandex.com"}
# Name: 5310, dtype: object
# backer_info    {"backer_id": "ka601", "cf_id": 1572, "name": "Kerstin Agostini", "email": "kagostini@live.com"}
# Name: 5311, dtype: object
# backer_info    {"backer_id": "cp165", "cf_id": 1911, "name": "Camelia Patterson", "email": "cpatterson@outlook.com"}
# Name: 5312, dtype: object
# backer_info    {"backer_id": "bg969", "cf_id": 65, "name": "Brendon Gould", "email": "bgould@yandex.com"}
# Name: 5313, dtype: object
# backer_info    {"backer_id": "ig621", "cf_id": 1572, "name": "Izola Giese", "email": "igiese@live.com"}
# Name: 5314, dtype: object
# backer_info    {"backer_id": "am726", "cf_id": 65, "name": "Alice Meunier", "email": "ameunier@yandex.com"}
# Name: 5315, dtype: object
# backer_info    {"backer_id": "nr816", "cf_id": 1114, "name": "Nohan Raggio", "email": "nraggio@outlook.com"}
# Name: 5316, dtype: object
# backer_info    {"backer_id": "vs478", "cf_id": 1572, "name": "Violette Sharpe", "email": "vsharpe@outlook.com"}
# Name: 5317, dtype: object
# backer_info    {"backer_id": "tb443", "cf_id": 968, "name": "Tracey Boehler", "email": "tboehler@outlook.com"}
# Name: 5318, dtype: object
# backer_info    {"backer_id": "hs993", "cf_id": 65, "name": "Helge Sartore", "email": "hsartore@outlook.com"}
# Name: 5319, dtype: object
# backer_info    {"backer_id": "pl812", "cf_id": 65, "name": "Pietro Lancaster", "email": "plancaster@outlook.com"}
# Name: 5320, dtype: object
# backer_info    {"backer_id": "tw537", "cf_id": 1572, "name": "Theola Wagner", "email": "twagner@yahoo.com"}
# Name: 5321, dtype: object
# backer_info    {"backer_id": "jl485", "cf_id": 563, "name": "Jamal Lacour", "email": "jlacour@yahoo.com"}
# Name: 5322, dtype: object
# backer_info    {"backer_id": "hc786", "cf_id": 563, "name": "Heidi Cammarano", "email": "hcammarano@live.com"}
# Name: 5323, dtype: object
# backer_info    {"backer_id": "ls932", "cf_id": 65, "name": "Lesley Schwarz", "email": "lschwarz@gmail.com"}
# Name: 5324, dtype: object
# backer_info    {"backer_id": "nm432", "cf_id": 65, "name": "Neville Morency", "email": "nmorency@outlook.com"}
# Name: 5325, dtype: object
# backer_info    {"backer_id": "np335", "cf_id": 65, "name": "Nordica Papi", "email": "npapi@gmail.com"}
# Name: 5326, dtype: object
# backer_info    {"backer_id": "zs732", "cf_id": 2488, "name": "Zia Stuart", "email": "zstuart@gmail.com"}
# Name: 5327, dtype: object
# backer_info    {"backer_id": "fb907", "cf_id": 1114, "name": "Fia Butler", "email": "fbutler@live.com"}
# Name: 5328, dtype: object
# backer_info    {"backer_id": "jh452", "cf_id": 968, "name": "Joshua Hirsch", "email": "jhirsch@gmail.com"}
# Name: 5329, dtype: object

# %%
# Create a backers_df DataFrame with the following columns: 'backer_id','cf_id', 'name', and 'email' 
# using the list of values lists.

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 2: Use regex
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Extract the "backer_id", "cf_id", "name", and "email using regular expressions."
# 3. Create a new DataFrame with the retrieved data.
# 4. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)

# %%
# Extract the alpha-numeric "backer_id" from the backer_info column using a regex expression 
# and add it as a new column called "backer_id".

# %%
# Extract the two to four-digit "cf_id" number from the backer_info column. 
# and add it as a new column called "cf_id".

# %%
# Extract the name from the backer_info column and add it as a new column called "name".

# %%
# Extract the email from the backer_info column and add it as a new column called "email".

# %%
# Create a new DataFrame with the appropriate columns.

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.

# %% [markdown]
# ## Deliverable 2: Transform and Clean Data
# ----
# 1. Check the data types of the columns and convert the "cf_id" column to an integer, if necessary.
# 2. Split the name in the "name" column into first and last names, and add them to "first_name" and "last_name" columns in the DataFrame.
# 3. Drop the "name" column in the DataFrame.
# 4. Place the columns in the following order; "backer_id", "cf_id", "first_name", "last_name" and "email".

# %%
# Check data types.

# %%
# Convert cf_id to an integer if necessary.

# %%
# Split the "name" column into "first_name" and "last_name" columns.

# %%
#  Drop the name column


# Reorder the columns

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
